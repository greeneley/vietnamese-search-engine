# %%
import numpy as np
from random import randint
import os
import json
import settings
import pickle as pickle
from fileProcess import FileReader, FileStore 
from preProcessData import FeatureExtraction, NLP
from pyvi import ViTokenizer
from sklearn.svm import LinearSVC
from gensim import corpora, matutils
from sklearn.metrics import classification_report
from argparse import ArgumentParser
import os.path

# %%
def is_valid_file(parser, arg):
    if not os.path.exists(arg):
        parser.error("The file %s does not exist!" % arg)
    else:
        return open(arg, 'r')   # return an open file handle

def readInput():
    parser = ArgumentParser(description="ikjMatrix multiplication")
    parser.add_argument("-i", dest="filename", required=True,
                        help="File need predict", metavar="FILE",
                        type=lambda x: is_valid_file(parser, x))
    args = parser.parse_args()
    return args.filename.read()

# %%
classifier = pickle.load(open('trained_model/logistic_model.pk','rb'))

# %%
classifier
# Out:
# LogisticRegression(C=30, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=20, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
# tf-idf
data = 'khách sạn'
vectorizer = pickle.load(open(settings.VECTOR_EMBEDDING,'rb'))
data_features = []
data_features.append(' '.join(NLP(text=data).remove_stopwords()))
features = vectorizer.transform(data_features)

# %%
vectorizer.get_feature_names()
# Out:
# ['adamo',
#  'adamo cung_cấp',
#  'adamo du_khách',
#  'adamo giúp',
#  'adamo mái',
#  'adamo sẽ',
#  'adamo với',
#  'ai',
#  'ai cũng',
#  'anh_đào',
#  'anh_đào cách',
#  'art',
#  'art gallery',
#  'art in',
#  'art và',
#  'babylon',
#  'babylon steak_garden',
#  'bambino',
#  'bambino và',
#  'bao_giờ',
#  'bao_giờ quên',
#  'bao_gồm',
#  'bao_gồm cape_nao',
#  'bao_gồm hai',
#  'bao_gồm nhân_viên',
#  'bao_gồm nén_restaurant',
#  'bao_gồm điều',
#  'bar',
#  'bar hoặc',
#  'bar mini',
#  'bar và',
#  'beach',
#  'beach hotel',
#  'beach_club',
#  'beach_club holy',
#  'beach_club km',
#  'beach_house',
#  'beach_house không',
#  'beach_house km',
#  'bi',
#  'bi và',
#  'biệt_thự',
#  'biệt_thự một',
#  'biệt_thự từ',
#  'boutique',
#  'boutique còn',
#  'boutique một',
#  'boutique ngoài_ra',
#  'boutique nằm',
#  'boutique sẽ',
#  'bài_trí',
#  'bài_trí ấn_tượng',
#  'bàn',
#  'bàn lễ_tân',
#  'bánh_xèo_bà',
#  'bánh_xèo_bà dưỡng',
#  'bõi',
#  'bõi ngoài_trời',
#  'bõi riêng',
#  'bước',
#  'bước chân',
#  'bạn',
#  'bạn chắc_chắn',
#  'bạn các',
#  'bạn có_thể',
#  'bạn cũng',
#  'bạn dễ_chịu',
#  'bạn gần',
#  'bạn khám_phá',
#  'bạn là',
#  'bạn lái_xe',
#  'bạn muốn',
#  'bạn nếu',
#  'bạn quãng',
#  'bạn sẽ',
#  'bạn thích',
#  'bạn thư',
#  'bạn trong',
#  'bạn trở_nên',
#  'bạn tìm_kiếm',
#  'bạn tận_hưởng',
#  'bạn tới',
#  'bạn và',
#  'bạn đang',
#  'bạn đi',
#  'bạn đà_nẵng',
#  'bạn được',
#  'bạn đến',
#  'bạn_bè',
#  'bạn_bè hoặc',
#  'bảo_tàng',
#  'bảo_tàng hồ_chí_minh',
#  'bảo_tàng lịch_sử',
#  'bảo_tàng mỹ_thuật',
#  'bảo_tàng nghệ_thuật',
#  'bảo_tàng quân_khu',
#  'bảo_tàng đà_nẵng',
#  'bận_rộn',
#  'bận_rộn với',
#  'bằng',
#  'bằng gỗ',
#  'bằng phương_tiện',
#  'bằng xe_cộ',
#  'bếp',
#  'bếp rộng',
#  'bể',
#  'bể bõi',
#  'bể_bơi',
#  'bể_bơi trên',
#  'bể_bơi và',
#  'bốn',
#  'bốn phòng',
#  'bồn_tắm',
#  'bồn_tắm nước',
#  'bộ',
#  'bộ từ',
#  'bởi',
#  'bởi khu',
#  'bởi khách_sạn',
#  'bữa',
#  'bữa sáng',
#  'cape_nao',
#  'cape_nao beach_club',
#  'cay_da_dai_thu',
#  'cay_da_dai_thu year',
#  'champa',
#  'champa ðền',
#  'chiều',
#  'chiều thơm',
#  'cho',
#  'cho bạn',
#  'cho các',
#  'cho du_khách',
#  'cho gia_đình',
#  'cho khách',
#  'cho khách_sạn',
#  'cho kì',
#  'cho kỳ',
#  'cho những',
#  'cho những_ai',
#  'cho phép',
#  'cho trẻ_em',
#  'cho việc',
#  'chuyên_nghiệp',
#  'chuyên_nghiệp một',
#  'chuyến',
#  'chuyến đi',
#  'chuẩn',
#  'chuẩn sao',
#  'chào_đón',
#  'chào_đón bạn',
#  'chân',
#  'chân từ',
#  'châu',
#  'châu ðặc',
#  'chõi',
#  'chõi cho',
#  'chúng_tôi',
#  'chúng_tôi chắc_chắn',
#  'chắc_chắn',
#  'chắc_chắn rằng',
#  'chắc_chắn sẽ',
#  'chắc_chắn thử',
#  'chỉ',
#  'chỉ cần',
#  'chỉ vài',
#  'chịu',
#  'chịu ảnh',
#  'cua',
#  'cua tại',
#  'cung',
#  'cung ðiện',
#  'cung_cấp',
#  'cung_cấp bàn',
#  'cung_cấp bể_bơi',
#  'cung_cấp bởi',
#  'cung_cấp cho',
#  'cung_cấp dịch_vụ',
#  'cung_cấp không_khí',
#  'cung_cấp nhân_viên',
#  'cung_cấp quầy',
#  'cung_cấp tv',
#  'cung_cấp điều',
#  'cà_phê',
#  'cà_phê khi',
#  'các',
#  'các biệt_thự',
#  'các cãn',
#  'các hoạt',
#  'các hoạt_động',
#  'các món',
#  'các nhà_hàng',
#  'các nhân_viên',
#  'các phòng',
#  'các tiện_ích',
#  'các địa_danh',
#  'cách',
#  'cách bài_trí',
#  'cách chỉ',
#  'cách ðó',
#  'câu',
#  'câu lạc_bộ',
#  'cãn',
#  'cãn biệt_thự',
#  'cãn bếp',
#  'còn',
#  'còn cung_cấp',
#  'còn có',
#  'có',
#  'có bể_bơi',
#  'có bồn_tắm',
#  'có các',
#  'có hồ',
#  'có khoảng',
#  'có khách',
#  'có sẵn',
#  'có thịt',
#  'có tôm_hùm',
#  'có xe_cộ',
#  'có được',
#  'có đỗ',
#  'có_thể',
#  'có_thể dùng',
#  'có_thể khám_phá',
#  'có_thể muốn',
#  'có_thể online',
#  'có_thể thưởng_thức',
#  'có_thể thử',
#  'có_thể tận',
#  'có_thể tận_hưởng',
#  'có_thể tới',
#  'có_thể vì',
#  'có_thể đây',
#  'công_tác',
#  'công_tác đi',
#  'cùng',
#  'cùng thiên_nhiên',
#  'cùng với',
#  'căn',
#  'căn phòng',
#  'cũng',
#  'cũng có_thể',
#  'cũng là',
#  'cũng xứng_đáng',
#  'cạnh',
#  'cạnh furama_resort',
#  'cả',
#  'cả hai',
#  'cần',
#  'cần phút',
#  'cầu',
#  'cầu sông_hàn',
#  'cẩm_thạch',
#  'cẩm_thạch và',
#  'của',
#  'của bạn',
#  'của khách',
#  'của kiến_trúc',
#  'của mình',
#  'của naman_retreat',
#  'của nhật_bản',
#  'của những',
#  'của paris_deli',
#  'của unesco',
#  'của vinpearl_luxury',
#  'của đà_nẵng',
#  'của đất_nước',
#  'của ẩm_thực',
#  'cửa_hiệu',
#  'cửa_hiệu ăn_uống',
#  'cửa_hàng',
#  'cửa_hàng cửa_hiệu',
#  'da_nang',
#  'da_nang bạn',
#  'da_nang cung_cấp',
#  'da_nang còn',
#  'da_nang hotel',
#  'da_nang khi',
#  'da_nang là',
#  'da_nang museum',
#  'da_nang ngoài_ra',
#  'da_nang sự',
#  'danang_restaurant',
#  'danang_restaurant bar',
#  'dhc',
#  'dhc marina',
#  'di_sản',
#  'di_sản hội_an',
#  'du_dương',
#  'du_dương hoặc',
#  'du_khách',
#  'du_khách có_thể',
#  'du_khách như',
#  'du_khách wifi',
#  'du_khách đến',
#  'du_lịch',
#  'du_lịch hilton',
#  'du_lịch hãy',
#  'du_lịch khi',
#  'du_lịch như',
#  'du_lịch thích',
#  'du_lịch tiếp_tục',
#  'du_lịch tìm_kiếm',
#  'du_lịch đã',
#  'dành',
#  'dành cho',
#  'dù',
#  'dù bạn',
#  'dùng',
#  'dùng bàn',
#  'dùng đỗ',
#  'dýỡng',
#  'dýỡng chuẩn',
#  'dưỡng',
#  'dưỡng nếu',
#  'dấu_ấn',
#  'dấu_ấn của',
#  'dễ_chịu',
#  'dễ_chịu hơn',
#  'dễ_chịu nhất',
#  'dễ_dàng',
#  'dễ_dàng giúp',
#  'dễ_dàng kết_nối',
#  'dễ_dàng nhất',
#  'dễ_dàng vì',
#  'dễ_dàng với',
#  'dịch_vụ',
#  'dịch_vụ có',
#  'dịch_vụ phòng',
#  'ebi_sashimi',
#  'ficus',
#  'ficus km',
#  'filet',
#  'filet mignon',
#  'furama_resort',
#  'furama_resort ðà_nẵng',
#  'furama_villas',
#  'furama_villas và',
#  'fusion',
#  'fusion maia',
#  'fusion_maia',
#  'fusion_maia giúp',
#  'fusion_maia hotel',
#  'fusion_maia khu',
#  'fusion_maia mái',
#  'fusion_maia nếu',
#  'fusion_maia sẽ',
#  'gallery',
#  'gallery dù',
#  'gallery đều',
#  'gia',
#  'gia ðình',
#  'gia_đình',
#  'gia_đình cùng',
#  'giàu',
#  'giàu kinh_nghiệm',
#  'giá_trị',
#  'giá_trị của',
#  'giá_trị lý_tưởng',
#  'giây_phút',
#  'giây_phút nghỉ_ngơi',
#  'giây_phút thư_giãn',
#  'giãn',
#  'giãn nghỉ_ngơi',
#  'giãn tại',
#  'giúp',
#  'giúp bạn',
#  'giúp chuyến',
#  'giúp khách',
#  'giúp kì',
#  'giải_trí',
#  'giải_trí bạn',
#  'giải_trí da_nang',
#  'giải_trí the_workshop',
#  'giờ',
#  'giờ nhân_viên',
#  'giờ sáng',
#  'giờ sân_thượng',
#  'gì',
#  'gì naman_retreat',
#  'gì tuyệt',
#  'gì vinpearl_luxury',
#  'gần',
#  'gần các',
#  'gần nhà_hàng',
#  'gần với',
#  'gồm',
#  'gồm các',
#  'gỗ',
#  'gỗ và',
#  'hai',
#  'hai bể',
#  'hai naman',
#  'hai ðến',
#  'haian',
#  'haian beach',
#  'hay',
#  'hay cả',
#  'hilton',
#  'hilton da_nang',
#  'hilton_da_nang',
#  'hilton_da_nang bao_gồm',
#  'hilton_da_nang là',
#  'hiện',
#  'hiện ðại',
#  'hoa',
#  'hoa anh_đào',
#  'holy',
#  'holy pig',
#  'holy_pig',
#  'holy_pig hoặc',
#  'hotel',
#  'hotel bao_gồm',
#  'hotel cung_cấp',
#  'hotel gần',
#  'hotel làm',
#  'hotel mong_muốn',
#  'hotel nằm',
#  'hotel spa',
#  'hotel trở_thành',
#  'hotel đỗ',
#  'hoàng_gia',
#  'hoàng_gia và',
#  'hoạt',
#  'hoạt ðộng',
#  'hoạt_động',
#  'hoạt_động giải_trí',
#  'hoạt_động trong',
#  'hoặc',
#  'hoặc babylon',
#  'hoặc bánh_xèo_bà',
#  'hoặc bảo_tàng',
#  'hoặc gia',
#  'hoặc lam_vien',
#  'hoặc nhà_hàng',
#  'hoặc sofia_restaurant',
#  'hoặc the_grill',
#  'hoặc thùng',
#  'hoặc thưởng_thức',
#  'hung',
#  'hung stone_arts',
#  'hài_lòng',
#  'hài_lòng của',
#  'hàng_đầu',
#  'hàng_đầu của',
#  'hàng_đầu và',
#  'hãy',
#  'hãy chắc_chắn',
#  'hãy khám_phá',
#  'hãy nhớ',
#  'hãy thử',
#  'hãy thử_nghiệm',
#  'hãy tận_hưởng',
#  'hãy tự',
#  'hòa',
#  'hòa cùng',
#  'hòa nhiệt_độ',
#  'hýởng',
#  'hýởng của',
#  'hýởng một',
#  'hýởng nhiều',
#  'hơn',
#  'hơn nếu',
#  'hơn nữa',
#  'hơn_nữa',
#  'hơn_nữa khách',
#  'hơn_nữa khách_sạn',
#  'hơn_nữa là',
#  'hải_sản_bé',
#  'hải_sản_bé mặn',
#  'họ',
#  'họ mong_muốn',
#  'hỏi',
#  'hỏi tại_sao',
#  'hồ',
#  'hồ bõi',
#  'hồ_chí_minh',
#  'hồ_chí_minh đều',
#  'hỗ_trợ',
#  'hỗ_trợ khách',
#  'hội_an',
#  'hội_an của',
#  'hữu_ích',
#  'hữu_ích cho',
#  'in',
#  'in paradise',
#  'internet',
#  'internet trong',
#  'internet trở_nên',
#  'internet được',
#  'ise',
#  'ise ebi_sashimi',
#  'khi',
#  'khi khách_sạn',
#  'khi nghỉ',
#  'khi đà_nẵng',
#  'khi đây',
#  'khi đến',
#  'khoảng',
#  'khoảng thời_gian',
#  'khoảng đi',
#  'khu',
#  'khu nghỉ_dưỡng',
#  'khu phức_hợp',
#  'khung_cảnh',
#  'khung_cảnh dành',
#  'khung_cảnh thời_thượng',
#  'khách',
#  'khách có',
#  'khách có_thể',
#  'khách du_lịch',
#  'khách hơn_nữa',
#  'khách khách',
#  'khách khách_sạn',
#  'khách lýu',
#  'khách nhiều',
#  'khách nếu',
#  'khách trong',
#  'khách và',
#  'khách đi',
#  'khách đi_lại',
#  'khách_hàng',
#  'khách_hàng giá_trị',
#  'khách_sạn',
#  'khách_sạn adamo',
#  'khách_sạn bằng',
#  'khách_sạn bể_bơi',
#  'khách_sạn cung_cấp',
#  'khách_sạn còn',
#  'khách_sạn khách',
#  'khách_sạn là',
#  'khách_sạn lãng_mạn',
#  'khách_sạn quyến_rũ',
#  'khách_sạn sang_trọng',
#  'khách_sạn sau',
#  'khách_sạn sen',
#  'khách_sạn trở_thành',
#  'khám_phá',
#  'khám_phá dhc',
#  'khám_phá một',
#  'khám_phá những',
#  'khám_phá phòng',
#  'khám_phá viện',
#  'khám_phá đà_nẵng',
#  'khó',
#  'khó chào_đón',
#  'không',
#  'không bao_giờ',
#  'không bạn',
#  'không phải',
#  'không thiếu',
#  'không xa',
#  'không_khí',
#  'không_khí dành',
#  'không_khí sang_trọng',
#  'khỏi',
#  'khỏi một',
#  'kinh_nghiệm',
#  'kinh_nghiệm và',
#  'kiến_trúc',
#  'kiến_trúc champa',
#  'kiểu',
#  'kiểu có_thể',
#  'kiểu như',
#  'km',
#  'km các',
#  'km haian',
#  'km hilton',
#  'km khách',
#  'km không',
#  'km một',
#  'km nhà_hàng',
#  'km nằm',
#  'km nếu',
#  'km thien_ly',
#  'km và',
#  'km đã',
#  'kobe',
#  'kobe ya_đặc_trưng',
#  'kì',
#  'kì nghỉ',
#  'kết_nối',
#  'kết_nối internet',
#  'kết_nối khi',
#  'kết_nối_mạng',
#  'kết_nối_mạng là',
#  'kết_nối_mạng thật',
#  'kỳ',
#  'kỳ nghỉ',
#  'lam_pagoda',
#  'lam_pagoda km',
#  'lam_vien',
#  'lam_vien restaurant',
#  'le',
#  'le bambino',
#  'linh_ung_pagoda',
#  'linh_ung_pagoda km',
#  'lo_lắng',
#  'lo_lắng gì',
#  'lounge',
#  'lounge mở_cửa',
#  'loạt',
#  'loạt tiện_nghi',
#  'ly',
#  'ly trà',
#  'là',
#  'là có_thể',
#  'là khách_hàng',
#  'là khách_sạn',
#  'là lý_do',
#  'là lựa_chọn',
#  'là một',
#  'là ngôi',
#  'là những',
#  'là nơi',
#  'là quá',
#  'là sự',
#  'là với',
#  'là đỗ',
#  'làm',
#  'làm cho',
#  'làm chuyến',
#  'làm paris_deli',
#  'làm_việc',
#  'làm_việc trong',
#  'lái_xe',
#  'lái_xe du_khách',
#  'lái_xe tới',
#  'lái_xe ðến',
#  'lân',
#  'lân hoặc',
#  'lân_cận',
#  'lân_cận như',
#  'lãng_mạn',
#  'lãng_mạn lý_tưởng',
#  'lên',
#  'lên hàng_đầu',
#  'lý_do',
#  'lý_do tại_sao',
#  'lý_tưởng',
#  'lý_tưởng cho',
#  'lý_tưởng của',
#  'lý_tưởng sự',
#  'lý_tưởng đà_nẵng',
#  'lýu',
#  'lýu trú',
#  'lưu_trú',
#  'lưu_trú thư_giãn',
#  'lạc_bộ',
#  'lạc_bộ trẻ_em',
#  'lại',
#  'lại những',
#  'lại sự',
#  'lẩu',
#  'lẩu có_thể',
#  'lễ_tân',
#  'lễ_tân giờ',
#  'lịch_sử',
#  'lịch_sử như',
#  'lựa_chọn',
#  'lựa_chọn haian',
#  'lựa_chọn lý_tưởng',
#  'lựa_chọn phổ_biến',
#  'lựa_chọn tuyệt_vời',
#  'lựa_chọn vinpearl_resort',
#  'lựa_chọn đúng_đắn',
#  'madame',
#  'madame lân',
#  'madame_lân',
#  'madame_lân quan_com_hue',
#  'maia',
#  'maia hotel',
#  'maki',
#  'maki sashimi',
#  'mang',
#  'mang lại',
#  'mang đậm',
#  'mang đến',
#  'marina',
#  'marina km',
#  'mignon',
#  'mignon như',
#  'mini',
#  'mini trong',
#  'mini tủ_lạnh',
#  'mini và',
#  'mini đưa',
#  'miễn_phí',
#  'miễn_phí có',
#  'miễn_phí khi',
#  'miễn_phí khách_sạn',
#  'miễn_phí nhân_viên',
#  'miễn_phí sẵn',
#  'miễn_phí trong',
#  'mong_muốn',
#  'mong_muốn được',
#  'moriawase',
#  'moriawase và',
#  'museum',
#  'museum bảo_tàng',
#  'museum và',
#  'muốn',
#  'muốn khám_phá',
#  'muốn thử',
#  'muốn đến',
#  'màn_hình_phẳng',
#  'màn_hình_phẳng quầy',
#  'màn_hình_phẳng điều',
#  'mái',
#  'mái ngói',
#  'mái nhà',
#  'mát',
#  'mát nơi',
#  'mình',
#  'mình có_thể',
#  'mình đỗ',
#  'món',
#  'món teniyu',
#  'món ãn',
#  'món ăn',
#  'mặn',
#  'mặn le',
#  'mặn madame',
#  'mặt_trời',
#  'mặt_trời mọc',
#  'mọc',
#  'mọc phòng',
#  'một',
#  'một câu',
#  'một khu',
#  'một kỳ',
#  'một lựa_chọn',
#  'một ngày',
#  'một nét',
#  'một trong',
#  'một điểm',
#  'một_cách',
#  'một_cách nhanh_chóng',
#  'một_số',
#  'một_số nhà_hàng',
#  'một_số tiện_nghi',
#  'một_số địa_danh',
#  'mở_cửa',
#  'mở_cửa ðến',
#  'mỹ_thuật',
#  'mỹ_thuật đà_nẵng',
#  'naman',
#  'naman retreat',
#  'naman_retreat',
#  'naman_retreat bạn',
#  'naman_retreat cung_cấp',
#  'naman_retreat sẽ',
#  'nghiệm',
#  'nghiệm thú_vị',
#  'nghệ_thuật',
#  'nghệ_thuật nổi_tiếng',
#  'nghỉ',
#  'nghỉ của',
#  'nghỉ dýỡng',
#  'nghỉ hãy',
#  'nghỉ sắp',
#  'nghỉ tại',
#  'nghỉ_dưỡng',
#  'nghỉ_dưỡng bao_gồm',
#  'nghỉ_dưỡng cung_cấp',
#  'nghỉ_dưỡng fusion_maia',
#  'nghỉ_dưỡng hay',
#  'nghỉ_ngơi',
#  'nghỉ_ngơi không',
#  'nghỉ_ngơi naman_retreat',
#  'nghỉ_ngơi và',
#  'ngon',
#  'ngon hoặc',
#  'ngon nhà_hàng',
#  'ngon trong',
#  'ngoài_ra',
#  'ngoài_ra khách_sạn',
#  'ngoài_ra vinpearl_resort',
#  'ngoài_trời',
#  'ngoài_trời quán',
#  'ngày',
#  'ngày bận_rộn',
#  'ngói',
#  'ngói ðỏ',
#  'ngôi',
#  'ngôi nhà',
#  'ngũ',
#  'ngũ nhân_viên',
#  'ngũ_hành',
#  'ngũ_hành sõn',
#  'người',
#  'người làm_việc',
#  'ngủ',
#  'ngủ có',
#  'nhanh_chóng',
#  'nhanh_chóng và',
#  'nhiều',
#  'nhiều dịch_vụ',
#  'nhiều khách',
#  'nhiều năm',
#  'nhiều tiện_nghi',
#  'nhiệt_độ',
#  'nhiệt_độ và',
#  'nhà',
#  'nhà xa',
#  'nhà_hàng',
#  'nhà_hàng beach_house',
#  'nhà_hàng cách',
#  'nhà_hàng kiểu',
#  'nhà_hàng lân_cận',
#  'nhà_hàng naman',
#  'nhà_hàng nhật_bản',
#  'nhà_hàng nổi_tiếng',
#  'nhà_hàng panorama',
#  'nhà_hàng sang_trọng',
#  'nhân_viên',
#  'nhân_viên của',
#  'nhân_viên hỗ_trợ',
#  'nhân_viên phục_vụ',
#  'như',
#  'như art',
#  'như bạn',
#  'như cay_da_dai_thu',
#  'như da_nang',
#  'như dhc',
#  'như holy_pig',
#  'như hải_sản_bé',
#  'như khung_cảnh',
#  'như olivia',
#  'như quan_com_hue',
#  'như tu',
#  'nhạc',
#  'nhạc du_dương',
#  'nhất',
#  'nhất có_thể',
#  'nhất kì',
#  'nhất đà_nẵng',
#  'nhật_bản',
#  'nhật_bản là',
#  'nhật_bản theo',
#  'nhật_bản với',
#  'nhẹ',
#  'nhẹ đồ',
#  'nhớ',
#  'nhớ thử',
#  'những',
#  'những du_khách',
#  'những giá_trị',
#  'những giây_phút',
#  'những gì',
#  'những khách',
#  'những người',
#  'những nhà_hàng',
#  'những trải',
#  'những viện',
#  'những điểm',
#  'những địa_danh',
#  'những_ai',
#  'những_ai muốn',
#  'này',
#  'này bởi',
#  'này đà_nẵng',
#  'nén_restaurant',
#  'nén_restaurant km',
#  'nét',
#  'nét châu',
#  'nóng',
#  'nóng và',
#  'năm',
#  'năm nếu',
#  'năm trong',
#  'nơi',
#  'nơi bạn',
#  'nơi đây',
#  'nước',
#  'nước nóng',
#  'nướng',
#  'nướng lân_cận',
#  'nướng như',
#  'nằm',
#  'nằm cạnh',
#  'nằm không',
#  'nằm trong',
#  'nếu',
#  'nếu bạn',
#  'nếu không',
#  'nổi_tiếng',
#  'nổi_tiếng khi',
#  'nổi_tiếng như',
#  'nổi_tiếng với',
#  'nổi_tiếng đà_nẵng',
#  'nội_thất',
#  'nội_thất bằng',
#  'nữa',
#  'nữa còn',
#  'nữa khách_sạn',
#  'nữa thuận_tiện',
#  'nữa đó',
#  'oasis',
#  'oasis art',
#  'olivia',
#  'olivia prime_steakhouse',
#  'online',
#  'online là',
#  'online với',
#  'oriental_restaurant',
#  'oriental_restaurant km',
#  'panorama',
#  'panorama hoặc',
#  'paradise',
#  'paradise trick',
#  'paris_deli',
#  'paris_deli hotel',
#  'phap',
#  'phap lam_pagoda',
#  'phi_bbq',
#  'phi_bbq nếu',
#  'phong_cách',
#  'phong_cách kobe',
#  'phong_cách truyền_thống',
#  'phong_phú',
#  'phong_phú đầu_bếp',
#  'phép',
#  'phép bạn',
#  'phòng',
#  'phòng hơn_nữa',
#  'phòng khi',
#  'phòng khu',
#  'phòng khách_sạn',
#  'phòng là',
#  'phòng làm',
#  'phòng ngủ',
#  'phòng tatami',
#  'phòng trưng_bày',
#  'phòng tại',
#  'phòng tập_thể_dục',
#  'phòng và',
#  'phòng với',
#  'phòng ăn',
#  'phút',
#  'phút lái_xe',
#  'phýõng',
#  'phýõng tây',
#  'phương_tiện',
#  'phương_tiện của',
#  'phải',
#  'phải lo_lắng',
#  'phải là',
#  'phổ_biến',
#  'phổ_biến của',
#  'phục_vụ',
#  'phục_vụ bạn',
#  'phục_vụ các',
#  'phục_vụ giàu',
#  'phức_hợp',
#  'phức_hợp tuyệt',
#  'pig',
#  'pig hoặc',
#  'prime_steakhouse',
#  'prime_steakhouse và',
#  'quan_com_hue',
#  'quan_com_hue ngon',
#  'quay',
#  'quay trở_lại',
#  'quyến_rũ',
#  'quyến_rũ đà_nẵng',
#  'quá',
#  'quá khó',
#  'quán',
#  'quán bar',
#  'quán cà_phê',
#  'quân_khu',
#  'quân_khu và',
#  'quãng',
#  'quãng thời_gian',
#  'quên',
#  'quầy',
#  'quầy bar',
#  'quốc_tế',
#  'quốc_tế ðà_nẵng',
#  'red',
#  'red sky_bar',
#  'resort',
#  'resort ðà_nẵng',
#  'restaurant',
#  'restaurant nếu',
#  'restaurant tất_cả',
#  'restaurant waterfront',
#  'retreat',
#  'retreat chắc_chắn',
#  'retreat sẽ',
#  'riêng',
#  'riêng và',
#  'rằng',
#  'rằng bạn',
#  'rộng',
#  'rộng ðýợc',
#  'sang_trọng',
#  'sang_trọng cung_cấp',
#  'sang_trọng cùng',
#  ...]

# %%
print(classifier.predict(features))
# Out:
# ['Khach San']

# %%
text_category = 'Healthy'

# %%
import requests

# %%
data_json = requests.get('https://api.viettelmaps.com.vn:8080/gateway/searching/v1/place-api/autocomplete?input='+text_category+' ca&center=16,108&access_token=f68f98d802ba6c0a60ee9dc44c47f48c')

# %%
data_json = data_json.json()

# %%
data_json
# Out:
# {'attributions': 'NOTICE: © 2019 ViettelMap and its suppliers. All rights reserved',
#  'data': [{'placeId': '59574a6a4c4459784e6a45784c4449314c47526c5a673d3d',
#    'text': 'BTOWN - Healthy Drinks and Cakes - Delivery Only Hoàng Văn Thụ, P. 4 Quận Tân Bình TP. HCM'},
#   {'placeId': '59574a6a4c4455784e7a6b794c4449334c47526c5a673d3d',
#    'text': 'Kem nhau thai cuu Healthy Care 398,13 Trường Chinh, Phường 12, Quận Tân Bình, Hồ Chí Minh'}]}
